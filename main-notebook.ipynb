# %%
import pandas as pd

# %%
df_meta= pd.read_csv('song_analysis-2.csv')

# %%
df_meta.head(20)
# Out:
#     Unnamed: 0  danceability  energy  key  loudness  mode  speechiness  \
# 0            0         0.468   0.763    9    -6.826     0       0.2680
# 1            1         0.571   0.605    7    -7.336     1       0.0410
# 2            2         0.692   0.785    7    -6.659     1       0.2240
# 3            3         0.680   0.501    6    -7.310     0       0.4860
# 4            4         0.848   0.721    1    -8.791     1       0.2620
# 5            5         0.773   0.610    2    -8.004     1       0.1230
# 6            6         0.726   0.818    0    -6.473     1       0.3110
# 7            7         0.584   0.722    9    -7.733     1       0.2800
# 8            8         0.686   0.824   11    -5.413     1       0.3400
# 9            9         0.603   0.764    7    -7.407     1       0.2870
# 10          10         0.595   0.878   10    -5.630     0       0.4230
# 11          11         0.805   0.539    1    -9.968     1       0.1790
# ...

# %%
df_names=pd.read_csv('id_names.csv')

# %%
df_names.head(20)
# Out:
#    Unnamed: 0                                                  0  \
# 0           0  pulling the pin (feat. Mavis Staples & Josh Ho...
# 1           1                             1uE4PBDSPZ0cT4do1bmT7A
#
#                                               1                       2  \
# 0  a few words for the firing squad (radiation)        the ground below
# 1                        1hxVQkhDJN2UnkgeqX68D3  30gsURaHDTPnDJDINiTCsK
#
#                                                    3                       4  \
# 0  JU$T (feat. Pharrell Williams & Zack de la Rocha)         never look back
# 1                             10vS4ZLi4XWlIsNXSQXgqh  3vrOmd6lTTKXGjaYeq8kni
#
#                         5                       6  \
# 0        goonies vs. E.T.     walking in the snow
# 1  3tDIjnh6wdwMWDHRHF97XC  2pVvB487ZwqdzTxEvEEors
#
#                                7                                         8  \
# 0  out of sight (feat. 2 Chainz)  ooh la la (feat. Greg Nice & DJ Premier)
# ...

# %%
df_names = df_names.transpose()

# %%
df_names.head()
# Out:
#                                                             0  \
# Unnamed: 0                                                  0
# 0           pulling the pin (feat. Mavis Staples & Josh Ho...
# 1                a few words for the firing squad (radiation)
# 2                                            the ground below
# 3           JU$T (feat. Pharrell Williams & Zack de la Rocha)
#
#                                  1
# Unnamed: 0                       1
# 0           1uE4PBDSPZ0cT4do1bmT7A
# 1           1hxVQkhDJN2UnkgeqX68D3
# 2           30gsURaHDTPnDJDINiTCsK
# 3           10vS4ZLi4XWlIsNXSQXgqh

# %%
df_names['id'] = df_names[1]

# %%
df_names.drop(columns=[1])
# Out:
#                                                             0  \
# Unnamed: 0                                                  0
# 0           pulling the pin (feat. Mavis Staples & Josh Ho...
# 1                a few words for the firing squad (radiation)
# 2                                            the ground below
# 3           JU$T (feat. Pharrell Williams & Zack de la Rocha)
# ...                                                       ...
# 995                              Year for Love: Upendo Riddim
# 996                                                  Showtime
# 997                                                      Hulk
# 998                                                O'Lawd Oye
# 999                                       Top Striker (Remix)
#
#                                 id
# Unnamed: 0                       1
# 0           1uE4PBDSPZ0cT4do1bmT7A
# 1           1hxVQkhDJN2UnkgeqX68D3
# 2           30gsURaHDTPnDJDINiTCsK
# 3           10vS4ZLi4XWlIsNXSQXgqh
# ...

# %%
df_names.columns
# Out:
# Index([0, 1, 'id'], dtype='object')

# %%
df_names['Name'] = df_names[0]

# %%
df_names.head()
# Out:
#                                                             0  \
# Unnamed: 0                                                  0
# 0           pulling the pin (feat. Mavis Staples & Josh Ho...
# 1                a few words for the firing squad (radiation)
# 2                                            the ground below
# 3           JU$T (feat. Pharrell Williams & Zack de la Rocha)
#
#                                  1                      id  \
# Unnamed: 0                       1                       1
# 0           1uE4PBDSPZ0cT4do1bmT7A  1uE4PBDSPZ0cT4do1bmT7A
# 1           1hxVQkhDJN2UnkgeqX68D3  1hxVQkhDJN2UnkgeqX68D3
# 2           30gsURaHDTPnDJDINiTCsK  30gsURaHDTPnDJDINiTCsK
# 3           10vS4ZLi4XWlIsNXSQXgqh  10vS4ZLi4XWlIsNXSQXgqh
#
#                                                          Name
# Unnamed: 0                                                  0
# 0           pulling the pin (feat. Mavis Staples & Josh Ho...
# ...

# %%
df_names = df_names.drop(columns=[0,1])

# %%
df_names
# Out:
#                                 id  \
# Unnamed: 0                       1
# 0           1uE4PBDSPZ0cT4do1bmT7A
# 1           1hxVQkhDJN2UnkgeqX68D3
# 2           30gsURaHDTPnDJDINiTCsK
# 3           10vS4ZLi4XWlIsNXSQXgqh
# ...                            ...
# 995         0JchMDD8gIEsAOt8Qo01m2
# 996         0Eheksy6LPSSe7mWaDzxvQ
# 997         2ZDKd8948mNqGCe61ZgnPp
# 998         0SYeRcYIUAMFgyhfNMFCPO
# 999         3LP9Bx6xO4foAPvDcT1bqV
#
#                                                          Name
# Unnamed: 0                                                  0
# 0           pulling the pin (feat. Mavis Staples & Josh Ho...
# 1                a few words for the firing squad (radiation)
# 2                                            the ground below
# 3           JU$T (feat. Pharrell Williams & Zack de la Rocha)
# ...                                                       ...
# 995                              Year for Love: Upendo Riddim
# ...

# %%
 df_names = df_names.iloc[1:]

# %%
df_names
# Out:
#                          id                                               Name
# 0    1uE4PBDSPZ0cT4do1bmT7A  pulling the pin (feat. Mavis Staples & Josh Ho...
# 1    1hxVQkhDJN2UnkgeqX68D3       a few words for the firing squad (radiation)
# 2    30gsURaHDTPnDJDINiTCsK                                   the ground below
# 3    10vS4ZLi4XWlIsNXSQXgqh  JU$T (feat. Pharrell Williams & Zack de la Rocha)
# 4    3vrOmd6lTTKXGjaYeq8kni                                    never look back
# ..                      ...                                                ...
# 995  0JchMDD8gIEsAOt8Qo01m2                       Year for Love: Upendo Riddim
# 996  0Eheksy6LPSSe7mWaDzxvQ                                           Showtime
# 997  2ZDKd8948mNqGCe61ZgnPp                                               Hulk
# 998  0SYeRcYIUAMFgyhfNMFCPO                                         O'Lawd Oye
# 999  3LP9Bx6xO4foAPvDcT1bqV                                Top Striker (Remix)
#
# [1000 rows x 2 columns]

# %%
df_meta.columns
# Out:
# Index(['Unnamed: 0', 'danceability', 'energy', 'key', 'loudness', 'mode',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'type', 'id', 'uri', 'track_href', 'analysis_url',
#        'duration_ms', 'time_signature'],
#       dtype='object')

# %%
df_meta = df_meta.drop(columns=['Unnamed: 0'])

# %%
df_meta.head(20)
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.468   0.763    9    -6.826     0       0.2680       0.29100
# 1          0.571   0.605    7    -7.336     1       0.0410       0.05910
# 2          0.692   0.785    7    -6.659     1       0.2240       0.00117
# 3          0.680   0.501    6    -7.310     0       0.4860       0.02400
# 4          0.848   0.721    1    -8.791     1       0.2620       0.13400
# 5          0.773   0.610    2    -8.004     1       0.1230       0.01690
# 6          0.726   0.818    0    -6.473     1       0.3110       0.06020
# 7          0.584   0.722    9    -7.733     1       0.2800       0.01830
# 8          0.686   0.824   11    -5.413     1       0.3400       0.15700
# 9          0.603   0.764    7    -7.407     1       0.2870       0.05570
# 10         0.595   0.878   10    -5.630     0       0.4230       0.17200
# 11         0.805   0.539    1    -9.968     1       0.1790       0.14300
# ...

# %%
df_meta
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.468   0.763    9    -6.826     0       0.2680       0.29100
# 1           0.571   0.605    7    -7.336     1       0.0410       0.05910
# 2           0.692   0.785    7    -6.659     1       0.2240       0.00117
# 3           0.680   0.501    6    -7.310     0       0.4860       0.02400
# 4           0.848   0.721    1    -8.791     1       0.2620       0.13400
# ..            ...     ...  ...       ...   ...          ...           ...
# 995         0.756   0.742    8    -5.441     0       0.0446       0.06540
# 996         0.742   0.907    2    -4.154     1       0.0400       0.12100
# 997         0.758   0.938    8    -3.817     1       0.2300       0.01680
# 998         0.859   0.828    4    -5.969     1       0.1570       0.15700
# 999         0.678   0.871    5    -4.968     0       0.2540       0.06150
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %%
names = df_names['Name']
names.iloc[0]
# Out:
# 'pulling the pin (feat. Mavis Staples & Josh Homme)'

# %%
def addName(names):
    for i,name in enumerate(names):
        df_meta['Name'].iloc[i] = name
    df_meta.head()

# %%
addName(names)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Name'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-78-0d297ade200c> in <module>
# ----> 1 addName(names)
#
# ...

# %%
nameCol = df_meta['Name']

# %%
df_meta.drop(columns='Name', inplace = True)

# %%
df_meta.insert(0,'Name', nameCol)

# %%
df_meta

# %%
df_meta

# %%
df_meta.to_csv('data_cleaned.csv')

# %%
df_names.to_csv('ids.csv')

# %%
df_meta.head()

# %%
df_names.head()

# %%
from matplotlib import pyplot as plt

# %%
for i,name in enumerate(df_names['Name']):
    if '$' in name:
        string = ''
        for letter in name:
            if letter == '$':
                letter = 's' 
                string = string + letter
                df_names['Name'].iloc[i] = string
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_names['Name'].head(50)
# Out:
# 0     pulling the pin (feat. Mavis Staples & Josh Ho...
# 1          a few words for the firing squad (radiation)
# 2                                      the ground below
# 3                                                     s
# 4                                       never look back
# 5                                      goonies vs. E.T.
# 6                                   walking in the snow
# 7                         out of sight (feat. 2 Chainz)
# 8              ooh la la (feat. Greg Nice & DJ Premier)
# 9                                       holy calamafuck
# 10                         yankee and the brave (ep. 4)
# 11                                             Midnight
# 12                                       Doobie Ashtray
# 13    Maria I'm Drunk (feat. Justin Bieber & Young T...
# 14                                               HONEST
# 15                                      Break on Monday
# 16                          Workin’ Out - A Colors Show
# ...

# %%
plt.style.use('seaborn')
plt.scatter(df_meta.index,df_meta['danceability'])
plt.show()

# %%
plt.style.use('seaborn')
plt.scatter(df_meta.index,df_meta['energy'])
plt.show()

# %%
plt.style.use('seaborn')
plt.scatter(df_meta.index,df_meta['speechiness'])
plt.show()

# %%
plt.style.use('seaborn')
plt.scatter(df_meta.index,df_meta['instrumentalness'])
plt.show()

# %%
df_meta.columns
# Out:
# Index(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms',
#        'time_signature'],
#       dtype='object')

# %%
plt.style.use('seaborn')
plt.scatter(df_meta.index,df_meta['acousticness'])
plt.show()

# %%
plt.style.use('seaborn')
plt.scatter(df_meta.index,df_meta['liveness'])
plt.show()

# %%
plt.style.use('seaborn')
plt.scatter(df_meta.index,df_meta['tempo'])
plt.show()

# %%
plt.style.use('seaborn')
plt.scatter(df_meta.index,df_meta['valence'])
plt.show()

# %%
plt.style.use('seaborn')
plt.scatter(df_meta.index,df_meta['duration_ms'])
plt.show()

# %%
filt_speech = df_meta['speechiness'] > .6
filt_live = df_meta['liveness'] > .6
filt_instr = (df_meta['instrumentalness'] > .2) & (df_meta['instrumentalness'] < .6)

# %%
df_meta[filt_speech]
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 157         0.607   0.480    9    -7.833     1        0.635         0.451
# 169         0.611   0.714    9    -4.696     0        0.856         0.184
# 380         0.648   0.713    9    -4.696     0        0.855         0.184
#
#      instrumentalness  liveness  valence    tempo            type  \
# 157               0.0     0.357    0.142  171.332  audio_features
# 169               0.0     0.145    0.628  196.043  audio_features
# 380               0.0     0.145    0.627  196.558  audio_features
#
#                          id                                   uri  \
# 157  2pQUmVMJiuGx3Dh0daDcJz  spotify:track:2pQUmVMJiuGx3Dh0daDcJz
# 169  5lw8Mgb4LyhriPIC86gV6e  spotify:track:5lw8Mgb4LyhriPIC86gV6e
# 380  4vRaGGiQN6l2LiQxSFg6ZP  spotify:track:4vRaGGiQN6l2LiQxSFg6ZP
#
#                                             track_href  \
# 157  https://api.spotify.com/v1/tracks/2pQUmVMJiuGx...
# ...

# %%
df_names.iloc[[157,169,380]]
# Out:
#                          id                        Name
# 157  2pQUmVMJiuGx3Dh0daDcJz  Big Black Truck (with JID)
# 169  5lw8Mgb4LyhriPIC86gV6e  RNP (feat. Anderson .Paak)
# 380  4vRaGGiQN6l2LiQxSFg6ZP  RNP (feat. Anderson .Paak)

# %%
df_meta[filt_live].head()
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 9           0.603   0.764    7    -7.407     1       0.2870        0.0557
# 71          0.507   0.464    3    -8.531     0       0.1710        0.3980
# 72          0.400   0.650    5    -6.104     0       0.0466        0.0118
# 86          0.638   0.863    4    -5.221     0       0.1320        0.0520
# 127         0.685   0.789    7    -6.040     1       0.4150        0.3770
#
#      instrumentalness  liveness  valence    tempo            type  \
# 9            0.000000     0.621    0.382  119.942  audio_features
# 71           0.000026     0.603    0.277  147.984  audio_features
# 72           0.000076     0.791    0.150  107.989  audio_features
# 86           0.000055     0.685    0.226  120.077  audio_features
# 127          0.000000     0.688    0.527   96.301  audio_features
#
#                          id                                   uri  \
# ...

# %%
df_names.iloc[df_meta[filt_live].index].head()
# Out:
#                          id             Name
# 9    6tfrMstZ8tw7nZJ6HP0PyW  holy calamafuck
# 71   0IabpxMpUV7waD7U4uDIMJ       Impossible
# 72   4QhWbupniDd44EDtnh2bFJ         Pyramids
# 86   2K9Ovn1o2bTGqbsABGC6m3         Too Late
# 127  6Bxy3KpK4ygO2X9QAiOQ3W     ꞌCosmicꞌ.m4a

# %%
df_meta[filt_instr].head()
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 11         0.805   0.539    1    -9.968     1       0.1790        0.1430
# 29         0.714   0.243    0   -13.513     1       0.0479        0.6460
# 51         0.681   0.597    4   -12.623     0       0.0637        0.3780
# 69         0.500   0.821    5    -5.276     0       0.2900        0.0238
# 97         0.605   0.661   10    -9.476     0       0.0443        0.4550
#
#     instrumentalness  liveness  valence    tempo            type  \
# 11             0.513     0.107    0.600   94.580  audio_features
# 29             0.210     0.110    0.504  125.832  audio_features
# 51             0.582     0.125    0.486  148.018  audio_features
# 69             0.397     0.346    0.824  119.931  audio_features
# 97             0.326     0.109    0.259  144.968  audio_features
#
#                         id                                   uri  \
# 11  7g2BVLCYyGeVHGGFajED65  spotify:track:7g2BVLCYyGeVHGGFajED65
# ...

# %%
df_names.iloc[df_meta[filt_instr].index]
# Out:
#                          id                           Name
# 11   7g2BVLCYyGeVHGGFajED65                       Midnight
# 29   1rV59uezLaLErSyjNHPhTJ                     Paper Thin
# 51   7l8qR2ndOxgE9hbfQf6gxA                          47.48
# 69   4Deqxj2CgLcLWSsFwXBeFj                        Mirando
# 97   2746pcTPaE9FBHkvUivCsg                Life Round Here
# 194  37HiXJE6AXeMa9u8g1AH56                      Obamacare
# 197  3FtYbEfBqAlGO46NUDQSAt                  Electric Feel
# 198  0YuePEX4KyfLIPMdNLPwgQ                     Endors Toi
# 200  2Gl1Qdx5Px5kVYe0PQoGI0                    Be Above It
# 207  3CaRo5FhGdAIjUhUM006ES                           Time
# 217  6nPEzYFTkv17HH9Ec9zKal             Capture Land - Dub
# 302  5hzYhY7jXXNdflaNlV84OX               Still Not Butter
# 373  5e5MKPtJuFb8NaeSEyV5gD                   Say You Will
# 392  1kxeWHF9PrCVZHvVskv8lg                  Love Lockdown
# 569  42YrWn7KYjhJ2GfjTJ3HSY                           Work
# ...
